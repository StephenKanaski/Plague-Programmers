# %%
import pandas as pd

# %%
state_pops_csv = "nst-est2019-01.csv"

# %%
state_populations = pd.read_csv(state_pops_csv)
state_populations.head(10)
# Out:
#   table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)  \
# 0  Table 1. Annual Estimates of the Resident Popu...
# 1                                    Geographic Area
# 2                                                NaN
# 3                                      United States
# 4                                          Northeast
# 5                                            Midwest
# 6                                              South
# 7                                               West
# 8                                            Alabama
# 9                                             Alaska
#
#     Unnamed: 1      Unnamed: 2                          Unnamed: 3  \
# 0          NaN             NaN                                 NaN
# 1     1-Apr-10             NaN  Population Estimate (as of July 1)
# 2       Census  Estimates Base                                2010
# ...

# %%
state_pop1 = state_populations.drop([0,1,3,4,5,6,7])

# %%
state_pop1.head(10)
# Out:
#    table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)  \
# 2                                                 NaN
# 8                                             Alabama
# 9                                              Alaska
# 10                                            Arizona
# 11                                           Arkansas
# 12                                         California
# 13                                           Colorado
# 14                                        Connecticut
# 15                                           Delaware
# 16                               District of Columbia
#
#     Unnamed: 1      Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 2       Census  Estimates Base        2010        2011        2012
# 8    4,779,736       4,780,125   4,785,437   4,799,069   4,815,588
# 9      710,231         710,249     713,910     722,128     730,443
# ...

# %%
state_pop1.columns
# Out:
# Index(['table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')

# %%
state_pop1.rename(columns={"table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)":"State", "Unnamed: 12":"2019"})
# Out:
#                                                 State  Unnamed: 1  \
# 2                                                 NaN      Census
# 8                                             Alabama   4,779,736
# 9                                              Alaska     710,231
# 10                                            Arizona   6,392,017
# 11                                           Arkansas   2,915,918
# 12                                         California  37,253,956
# 13                                           Colorado   5,029,196
# 14                                        Connecticut   3,574,097
# 15                                           Delaware     897,934
# 16                               District of Columbia     601,723
# 17                                            Florida  18,801,310
# 18                                            Georgia   9,687,653
# 19                                             Hawaii   1,360,301
# ...

# %%
state_pop2 = state_pop1.dropna()

# %%
state_pop2
# Out:
#    table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)  \
# 8                                             Alabama
# 9                                              Alaska
# 10                                            Arizona
# 11                                           Arkansas
# 12                                         California
# 13                                           Colorado
# 14                                        Connecticut
# 15                                           Delaware
# 16                               District of Columbia
# 17                                            Florida
# 18                                            Georgia
# 19                                             Hawaii
# 20                                              Idaho
# 21                                           Illinois
# 22                                            Indiana
# ...

# %%
state_pop2.reset_index()
# Out:
#     index  \
# 0       8
# 1       9
# 2      10
# 3      11
# 4      12
# 5      13
# 6      14
# 7      15
# 8      16
# 9      17
# 10     18
# 11     19
# 12     20
# 13     21
# 14     22
# 15     23
# 16     24
# 17     25
# 18     26
# 19     27
# 20     28
# 21     29
# 22     30
# 23     31
# 24     32
# 25     33
# 26     34
# 27     35
# 28     36
# 29     37
# 30     38
# 31     39
# 32     40
# 33     41
# 34     42
# 35     43
# 36     44
# 37     45
# 38     46
# 39     47
# 40     48
# 41     49
# 42     50
# 43     51
# 44     52
# 45     53
# 46     54
# 47     55
# 48     56
# 49     57
# 50     58
# 51     60
#
#    table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)  \
# 0                                             Alabama
# 1                                              Alaska
# 2                                             Arizona
# 3                                            Arkansas
# ...

# %%
state_pop2.columns
# Out:
# Index(['table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')

# %%
state_pop3 = state_pop2.rename(columns={"table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)":"State", "Unnamed: 12":"2019"})

# %%
state_pop3
# Out:
#                    State  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 8                Alabama   4,779,736   4,780,125   4,785,437   4,799,069
# 9                 Alaska     710,231     710,249     713,910     722,128
# 10               Arizona   6,392,017   6,392,288   6,407,172   6,472,643
# 11              Arkansas   2,915,918   2,916,031   2,921,964   2,940,667
# 12            California  37,253,956  37,254,519  37,319,502  37,638,369
# 13              Colorado   5,029,196   5,029,319   5,047,349   5,121,108
# 14           Connecticut   3,574,097   3,574,147   3,579,114   3,588,283
# 15              Delaware     897,934     897,937     899,593     907,381
# 16  District of Columbia     601,723     601,767     605,226     619,800
# 17               Florida  18,801,310  18,804,564  18,845,537  19,053,237
# 18               Georgia   9,687,653   9,688,729   9,711,881   9,802,431
# 19                Hawaii   1,360,301   1,360,307   1,363,963   1,379,329
# ...

# %%
state_pops = state_pop3[['State', '2019']]

# %%
state_pops
# Out:
#                    State        2019
# 8                Alabama   4,903,185
# 9                 Alaska     731,545
# 10               Arizona   7,278,717
# 11              Arkansas   3,017,804
# 12            California  39,512,223
# 13              Colorado   5,758,736
# 14           Connecticut   3,565,287
# 15              Delaware     973,764
# 16  District of Columbia     705,749
# 17               Florida  21,477,737
# 18               Georgia  10,617,423
# 19                Hawaii   1,415,872
# 20                 Idaho   1,787,065
# 21              Illinois  12,671,821
# 22               Indiana   6,732,219
# 23                  Iowa   3,155,070
# 24                Kansas   2,913,314
# 25              Kentucky   4,467,673
# 26             Louisiana   4,648,794
# 27                 Maine   1,344,212
# 28              Maryland   6,045,680
# 29         Massachusetts   6,892,503
# 30              Michigan   9,986,857
# 31             Minnesota   5,639,632
# ...

# %%
state_pops.to_csv('state_populations.csv', index=False,)
